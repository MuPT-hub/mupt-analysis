# %% [markdown]
# # Tested on Coarse Grained .dump N = 60, # Chains = 1000

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.rdf import InterRDF
import matplotlib.pyplot as plt
u = mda.Universe("CG_1ns_non_linear_N_60_C_1000.dump", format="LAMMPSDUMP")
u.trajectory[0] # Frame 1 is taken here!

# print(u.atoms.types)

group1 = u.select_atoms("type 1 and index 1")
group2 = u.select_atoms("type 1")

# Initialize the RDF calculation (defaults: bins=75, range=(0, 15))
rdf = InterRDF(group1, group2, nbins=200, range=(0.0, 20.0))
rdf.run()

# Plot RDF
plt.figure(figsize=(8, 5))
plt.plot(rdf.bins, rdf.rdf, label='RDF (type 1 vs type 1)')
plt.ylabel('g(r)')
plt.title('Radial Distribution Function')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # So, it seems like the function has included the index 1 atom itself in group 2 that is why an unexpected peak is rendered at Distance = 0

# %% [markdown]
# # Let's exclude atom indexed 1 from group 2

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.rdf import InterRDF
import matplotlib.pyplot as plt
u = mda.Universe("CG_1ns_non_linear_N_60_C_1000.dump", format="LAMMPSDUMP")
u.trajectory[0] # Frame 1 is taken here!

# print(u.atoms.types)

group1 = u.select_atoms("type 1 and index 1")
group2 = u.select_atoms("type 1 and not index 1")

# Initialize the RDF calculation (defaults: bins=75, range=(0, 15))
rdf = InterRDF(group1, group2, nbins=200, range=(0.0, 20.0))
rdf.run()

# Plot RDF
plt.figure(figsize=(8, 5))
plt.plot(rdf.bins, rdf.rdf, label='RDF (type 1 vs type 1)')
plt.ylabel('g(r)')
plt.title('Radial Distribution Function')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Testing with AA dump

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.rdf import InterRDF
import matplotlib.pyplot as plt
u = mda.Universe("AA_2ns_non_linear_PS_NRU_10_C_6.lammpstrj", format="LAMMPSDUMP")
u.trajectory[0] # Frame 1 is taken here!

# print(u.atoms.types)

group1 = u.select_atoms("resid 1 and index 1") # moleule id and atom in that molecule
group2 = u.select_atoms("resid 1") # molecule id

# Initialize the RDF calculation (defaults: bins=75, range=(0, 15))
rdf = InterRDF(group1, group2, nbins=200, range=(0.0, 20.0))
rdf.run()

# Plot RDF
plt.figure(figsize=(8, 5))
plt.plot(rdf.bins, rdf.rdf, label='RDF (type 1 vs type 1)')
plt.ylabel('g(r)')
plt.title('Radial Distribution Function')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.rdf import InterRDF
import matplotlib.pyplot as plt
u = mda.Universe("AA_2ns_non_linear_PS_NRU_10_C_6.lammpstrj", format="LAMMPSDUMP")
u.trajectory[0] # Frame 1 is taken here!

# print(u.atoms.types)

group1 = u.select_atoms("resid 1 and index 1")
group2 = u.select_atoms("resid 1 and not index 1")

# Initialize the RDF calculation (defaults: bins=75, range=(0, 15))
rdf = InterRDF(group1, group2, nbins=200, range=(0.0, 20.0))
rdf.run()

# Plot RDF
plt.figure(figsize=(8, 5))
plt.plot(rdf.bins, rdf.rdf, label='RDF (type 1 vs type 1)')
plt.ylabel('g(r)')
plt.title('Radial Distribution Function')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Polydisperse CG trajectory

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.rdf import InterRDF
import matplotlib.pyplot as plt
u = mda.Universe("../MSD_reference/CG_1ns_non_linear_PDI_1.5_C_1000.dump", format="LAMMPSDUMP")
u.trajectory[0] # Frame 1 is taken here!

# print(u.atoms.types)

group1 = u.select_atoms("type 1 and index 1")
group2 = u.select_atoms("type 1 and not index 1")

# Initialize the RDF calculation (defaults: bins=75, range=(0, 15))
rdf = InterRDF(group1, group2, nbins=200, range=(0.0, 15.0))
rdf.run()

# Plot RDF
plt.figure(figsize=(8, 5))
plt.plot(rdf.bins, rdf.rdf, label='RDF (type 1 vs type 1)')
plt.ylabel('g(r)')
plt.title('Radial Distribution Function')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
